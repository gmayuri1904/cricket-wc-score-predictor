# %%
import pickle
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error

# %%
df=pickle.load(open('dataset_level2.pkl','rb'))

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
cities=np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city']=cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#                       venue
# 0  Melbourne Cricket Ground
# 1  Melbourne Cricket Ground
# 2  Melbourne Cricket Ground
# 3  Melbourne Cricket Ground
# 4  Melbourne Cricket Ground

# %%
eligible_cities=df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
df=df[df['city'].isin(eligible_cities)]

# %%
df['current_score']=df.groupby('match_id').cumsum()['runs']

# %%
df['over']=df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no']=df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df['balls_bowled']=(df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
df['balls_left']=120-df['balls_bowled']
df['balls_left']=df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city                     venue  current_score over ball_no  \
# 0    Melbourne  Melbourne Cricket Ground              0    0       1
# 1    Melbourne  Melbourne Cricket Ground              0    0       2
# 2    Melbourne  Melbourne Cricket Ground              1    0       3
# 3    Melbourne  Melbourne Cricket Ground              3    0       4
# 4    Melbourne  Melbourne Cricket Ground              3    0       5
# ..         ...                       ...            ...  ...     ...
# 121    Colombo       R Premadasa Stadium            125   19       3
# 122    Colombo       R Premadasa Stadium            125   19       4
# 123    Colombo       R Premadasa Stadium            125   19       5
# 124    Colombo       R Premadasa Stadium            127   19       6
# 125    Colombo       R Premadasa Stadium            128   19       7
#
#      balls_bowled  balls_left
# 0               1         119
# 1               2         118
# 2               3         117
# 3               4         116
# 4               5         115
# ..            ...         ...
# 121           117           3
# 122           118           2
# 123           119           1
# 124           120           0
# 125           121           0
#
# [50501 rows x 13 columns]

# %%
df['player_dismissed']=df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed']=df['player_dismissed'].astype('int')
df['player_dismissed']=df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left']=10-df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city                     venue  current_score over ball_no  \
# 0    Melbourne  Melbourne Cricket Ground              0    0       1
# 1    Melbourne  Melbourne Cricket Ground              0    0       2
# 2    Melbourne  Melbourne Cricket Ground              1    0       3
# 3    Melbourne  Melbourne Cricket Ground              3    0       4
# 4    Melbourne  Melbourne Cricket Ground              3    0       5
# ..         ...                       ...            ...  ...     ...
# 121    Colombo       R Premadasa Stadium            125   19       3
# 122    Colombo       R Premadasa Stadium            125   19       4
# 123    Colombo       R Premadasa Stadium            125   19       5
# 124    Colombo       R Premadasa Stadium            127   19       6
# 125    Colombo       R Premadasa Stadium            128   19       7
#
#      balls_bowled  balls_left  wickets_left
# 0               1         119            10
# 1               2         118            10
# 2               3         117            10
# 3               4         116            10
# 4               5         115            10
# ..            ...         ...           ...
# 121           117           3             2
# 122           118           2             2
# 123           119           1             1
# 124           120           0             1
# 125           121           0             1
#
# [50501 rows x 14 columns]

# %%
df['crr']=(df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city                     venue  current_score over ball_no  \
# 0    Melbourne  Melbourne Cricket Ground              0    0       1
# 1    Melbourne  Melbourne Cricket Ground              0    0       2
# 2    Melbourne  Melbourne Cricket Ground              1    0       3
# 3    Melbourne  Melbourne Cricket Ground              3    0       4
# 4    Melbourne  Melbourne Cricket Ground              3    0       5
# ..         ...                       ...            ...  ...     ...
# 121    Colombo       R Premadasa Stadium            125   19       3
# 122    Colombo       R Premadasa Stadium            125   19       4
# 123    Colombo       R Premadasa Stadium            125   19       5
# 124    Colombo       R Premadasa Stadium            127   19       6
# 125    Colombo       R Premadasa Stadium            128   19       7
#
#      balls_bowled  balls_left  wickets_left       crr
# 0               1         119            10  0.000000
# 1               2         118            10  0.000000
# 2               3         117            10  2.000000
# 3               4         116            10  4.500000
# 4               5         115            10  3.600000
# ..            ...         ...           ...       ...
# 121           117           3             2  6.410256
# 122           118           2             2  6.355932
# 123           119           1             1  6.302521
# 124           120           0             1  6.350000
# 125           121           0             1  6.347107
#
# [50501 rows x 15 columns]

# %%
groups=df.groupby('match_id')

match_ids=df['match_id'].unique()
last_five=[]
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five']=last_five

# %%
final_df=df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team', 'bowling_team','city','current_score','balls_left','wickets_left','crr',
'last_five','runs_x']]

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
X=final_df.drop(columns=['runs_x'])
y=final_df['runs_x']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=7)

# %%
X_train
# Out:
#       batting_team  bowling_team          city  current_score  balls_left  \
# 46940      England   West Indies        Mumbai            100          46
# 25134      England  South Africa      Barbados             75          68
# 1347   West Indies         India    Lauderhill            133          16
# 16138   Bangladesh  South Africa     Cape Town            131          16
# 32654  New Zealand       England     Pallekele             55          63
# ...            ...           ...           ...            ...         ...
# 49098  New Zealand       England         Delhi             39          89
# 18569  West Indies  South Africa  Johannesburg             50          57
# 39939    Sri Lanka       England    Chittagong            189           0
# 3271   Afghanistan   West Indies      St Kitts             34          81
# 2913    Bangladesh     Sri Lanka       Colombo             78          74
#
#        wickets_left        crr  last_five
# 46940             8   8.108108       39.0
# 25134             9   8.653846       38.0
# 1347              2   7.673077       36.0
# 16138             2   7.557692       27.0
# 32654             7   5.789474       26.0
# ...             ...        ...        ...
# 49098             9   7.548387       34.0
# 18569             7   4.761905       19.0
# 39939             6   9.450000       52.0
# 3271              7   5.230769       24.0
# 2913              9  10.173913       54.0
#
# [30781 rows x 8 columns]

# %%
trf=ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
                      ],remainder='passthrough')

# %%
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9862591854626565
# 1.70140252936159

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
new_df=pd.DataFrame({'batting_team':['England'],'bowling_team':['South Africa'],'city':'Mumbai','current_score':[60],'balls_left':[75],'wickets_left':[5],'crr':[7],'last_five':[35]})
pipe.predict(new_df)
# Out:
# array([142.12607], dtype=float32)
